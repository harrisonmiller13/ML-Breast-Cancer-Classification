# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
sns.set()
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import tpot as tp
import imblearn
from collections import Counter
from tpot import TPOTClassifier, TPOTRegressor
from imblearn.under_sampling import RandomUnderSampler, TomekLinks, ClusterCentroids 
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN 
from imblearn.combine import SMOTETomek, SMOTEENN
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier

# %%
bc2.isnull().sum()
# Out:
# Clump Thickness                  0
# Uniformity of Cell Size          0
# Uniformity of Cell Shape         0
# Marginal Adhesion                0
# Single Epithelial Cell Size      0
# Bare Nuclei                      0
# Bland Chromatin                  0
# Normal Nucleoli                  0
# Mitosis                          0
# Class                            0
# radius                         130
# mean_radius                    130
# texture                        130
# mean_texture                   130
# perimeter                      130
# mean_perimeter                 130
# area                           130
# mean_area                      130
# smoothness                     130
# mean_smoothness                130
# compactness                    130
# mean_compactness               130
# concavity                      130
# mean_concavity                 130
# concave_points                 130
# mean_concave_points            130
# symmetry                       130
# mean_symmetry                  130
# fractal_dimension              130
# mean_fractal_dimension         130
# dtype: int64

# %%
bc2 = pd.read_csv('bc_data.csv', header = [1])
bc2.drop(['Diagnosis','id_number.1'], axis = 1, inplace = True)
bc2.set_index('id_number', inplace = True)
bc_data_with_dummies = pd.get_dummies(bc2)

# %%
bc_data_full = bc_data_with_dummies.interpolate(method = 'linear',axis = 1)

# %%
bc_data_full.head()
# Out:
#            Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# id_number
# 1000025                5.0                      1.0                       1.0
# 1002945                5.0                      4.0                       4.0
# 1015425                3.0                      1.0                       1.0
# 1016277                6.0                      8.0                       8.0
# 1017023                4.0                      1.0                       1.0
#
#            Marginal Adhesion  Single Epithelial Cell Size  Bland Chromatin  \
# id_number
# 1000025                  1.0                          2.0              3.0
# 1002945                  5.0                          7.0              3.0
# 1015425                  1.0                          2.0              3.0
# 1016277                  1.0                          3.0              3.0
# 1017023                  3.0                          2.0              3.0
#
#            Normal Nucleoli  Mitosis  Class  radius  ...  Bare Nuclei_10  \
# id_number                                           ...
# 1000025                1.0      1.0    2.0   17.99  ...             0.0
# 1002945                2.0      1.0    2.0   20.57  ...             1.0
# 1015425                1.0      1.0    2.0   19.69  ...             0.0
# 1016277                7.0      1.0    2.0   11.42  ...             0.0
# 1017023                1.0      1.0    2.0   20.29  ...             0.0
#
#            Bare Nuclei_2  Bare Nuclei_3  Bare Nuclei_4  Bare Nuclei_5  \
# id_number
# 1000025              0.0            0.0            0.0            0.0
# 1002945              0.0            0.0            0.0            0.0
# 1015425              1.0            0.0            0.0            0.0
# 1016277              0.0            0.0            1.0            0.0
# 1017023              0.0            0.0            0.0            0.0
#
#            Bare Nuclei_6  Bare Nuclei_7  Bare Nuclei_8  Bare Nuclei_9  \
# id_number
# 1000025              0.0            0.0            0.0            0.0
# 1002945              0.0            0.0            0.0            0.0
# 1015425              0.0            0.0            0.0            0.0
# 1016277              0.0            0.0            0.0            0.0
# 1017023              0.0            0.0            0.0            0.0
#
#            Bare Nuclei_?
# id_number
# 1000025              0.0
# 1002945              0.0
# 1015425              0.0
# 1016277              0.0
# 1017023              0.0
#
# [5 rows x 40 columns]

# %%
bc_data_full.columns
# Out:
# Index(['Clump Thickness', 'Uniformity of Cell Size',
#        'Uniformity of Cell Shape', 'Marginal Adhesion',
#        'Single Epithelial Cell Size', 'Bland Chromatin', 'Normal Nucleoli',
#        'Mitosis', 'Class', 'radius', 'mean_radius', 'texture', 'mean_texture',
#        'perimeter', 'mean_perimeter', 'area', 'mean_area', 'smoothness',
#        'mean_smoothness', 'compactness', 'mean_compactness', 'concavity',
#        'mean_concavity', 'concave_points', 'mean_concave_points', 'symmetry',
#        'mean_symmetry', 'fractal_dimension', 'mean_fractal_dimension',
#        'Bare Nuclei_1', 'Bare Nuclei_10', 'Bare Nuclei_2', 'Bare Nuclei_3',
#        'Bare Nuclei_4', 'Bare Nuclei_5', 'Bare Nuclei_6', 'Bare Nuclei_7',
#        'Bare Nuclei_8', 'Bare Nuclei_9', 'Bare Nuclei_?'],
#       dtype='object')

# %%
def plot_2d_space(X, y, label='Classes'):   
    colors = ['#1F77B4', '#FF7F0E']
    markers = ['o', 's']
    for l, c, m in zip(np.unique(y), colors, markers):
        plt.scatter(
            X[y==l, 0],
            X[y==l, 1],
            c=c, label=l, marker=m
        )
    plt.title(label)
    plt.legend(loc='upper right')
    plt.show()

# %%
#split into training and testing set
features = ['Clump Thickness', 'Uniformity of Cell Size',
       'Uniformity of Cell Shape', 'Marginal Adhesion',
       'Single Epithelial Cell Size', 'Bland Chromatin', 'Normal Nucleoli',
       'Mitosis', 'radius', 'mean_radius', 'texture', 'mean_texture',
       'perimeter', 'mean_perimeter', 'area', 'mean_area', 'smoothness',
       'mean_smoothness', 'compactness', 'mean_compactness', 'concavity',
       'mean_concavity', 'concave_points', 'mean_concave_points', 'symmetry',
       'mean_symmetry', 'fractal_dimension', 'mean_fractal_dimension',
       'Bare Nuclei_1', 'Bare Nuclei_10', 'Bare Nuclei_2', 'Bare Nuclei_3',
       'Bare Nuclei_4', 'Bare Nuclei_5', 'Bare Nuclei_6', 'Bare Nuclei_7',
       'Bare Nuclei_8', 'Bare Nuclei_9', 'Bare Nuclei_?']
X = bc_data_full[features]
y = bc_data_full['Class']
features_train,features_test,target_train,target_test = train_test_split(X,y, test_size = .25, random_state = 1 )

# %%
#Standardization before applying PCA
scaler = StandardScaler()
X_train = scaler.fit_transform(features_train)
print(X_train)
# Out:
# [[ 1.24812634 -0.05678383  0.24996077 ... -0.18311355 -0.09815249
#   -0.15309311]
#  [ 1.24812634  0.59716622  0.92165021 ... -0.18311355 -0.09815249
#   -0.15309311]
#  [ 1.24812634  1.5780913   1.92918438 ... -0.18311355 -0.09815249
#   -0.15309311]
#  ...
#  [-1.24676599 -0.05678383 -0.08588396 ... -0.18311355 -0.09815249
#   -0.15309311]
#  [-0.53393961 -0.71073388  0.24996077 ... -0.18311355 -0.09815249
#    6.53197265]
#  [ 0.53529996 -0.38375886 -0.7575734  ... -0.18311355 -0.09815249
#   -0.15309311]]

# %%
scaler2 = StandardScaler()
X_test = scaler2.fit_transform(features_test)

# %%
pca_columns = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20','PC21','PC22','PC23','PC24','PC25','PC26','PC27','PC28','PC29']

# %%
#Fitting training PCA
pca = PCA(n_components=29)
X_train_pca = pca.fit_transform(X_train)
principalDF = pd.DataFrame(data = X_train_pca, columns = pca_columns )
print("original shape:   ", X_train.shape)
print("transformed shape:", X_train_pca.shape)
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))

#plot_2d_space(pca_result, y, ' 29 PCA components')
# Out:
# original shape:    (524, 39)
# transformed shape: (524, 29)
# Explained variation per principal component: [3.82495575e-01 1.62986727e-01 7.33323720e-02 3.24405923e-02
#  3.02020595e-02 2.95677102e-02 2.80801540e-02 2.73948168e-02
#  2.67846394e-02 2.65584993e-02 2.63982703e-02 2.61352166e-02
#  2.30229296e-02 1.93696049e-02 1.49190850e-02 1.28478226e-02
#  1.16281071e-02 9.96021439e-03 8.31837721e-03 7.86937974e-03
#  6.29411037e-03 6.07289501e-03 3.41449257e-03 2.02799630e-03
#  1.31842518e-03 2.28791684e-04 1.59863683e-04 1.00025535e-04
#  2.62971797e-05]

# %%
#fitting testing PCA
pca2 = PCA(n_components = 29)
X_test_pca = pca2.fit_transform(X_test)
testprincipalDF = pd.DataFrame(data = X_test_pca, columns = pca_columns)
print("original shape:   ", features_test.shape)
print("transformed shape:", X_test_pca.shape)
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# original shape:    (175, 39)
# transformed shape: (175, 29)
# Explained variation per principal component: [3.82495575e-01 1.62986727e-01 7.33323720e-02 3.24405923e-02
#  3.02020595e-02 2.95677102e-02 2.80801540e-02 2.73948168e-02
#  2.67846394e-02 2.65584993e-02 2.63982703e-02 2.61352166e-02
#  2.30229296e-02 1.93696049e-02 1.49190850e-02 1.28478226e-02
#  1.16281071e-02 9.96021439e-03 8.31837721e-03 7.86937974e-03
#  6.29411037e-03 6.07289501e-03 3.41449257e-03 2.02799630e-03
#  1.31842518e-03 2.28791684e-04 1.59863683e-04 1.00025535e-04
#  2.62971797e-05]

# %%
target_test.shape
# Out:
# (175,)

# %%
eig_values = pca.explained_variance_
eig_vectors = pca.components_
print(eig_values)
print(eig_vectors)
# Out:
# [1.49458500e+01 6.36863625e+00 2.86543089e+00 1.26760219e+00
#  1.18013248e+00 1.15534556e+00 1.09721994e+00 1.07044068e+00
#  1.04659826e+00 1.03776193e+00 1.03150106e+00 1.02122235e+00
#  8.99611069e-01 7.56858980e-01 5.82956828e-01 5.02023139e-01
#  4.54363284e-01 3.89191092e-01 3.25037011e-01 3.07492628e-01
#  2.45939655e-01 2.37295760e-01 1.33419828e-01 7.92430829e-02
#  5.15168968e-02 8.93993663e-03 6.24660464e-03 3.90845476e-03
#  1.02755098e-03]
# [[-0.03448161 -0.01618502 -0.01963067 ... -0.01150041 -0.01240028
#   -0.01925216]
#  [ 0.294239    0.36416576  0.36097177 ...  0.09286093  0.0410768
#   -0.0114732 ]
#  [-0.03481445 -0.00694735  0.01312034 ... -0.01006279 -0.05810507
#   -0.03168157]
#  ...
#  [ 0.00105181 -0.01763708  0.00376703 ... -0.00067354 -0.0025298
#    0.00406315]
#  [-0.00165534 -0.00850393  0.00826052 ... -0.0021773  -0.00373302
#    0.0043426 ]
#  [-0.00221506 -0.00148192  0.00097179 ...  0.00123651  0.00141878
#   -0.00086797]]

# %%
eig_vectors[1]
# Out:
# array([ 0.294239  ,  0.36416576,  0.36097177,  0.3145847 ,  0.3079558 ,
#         0.32852915,  0.31329384,  0.20180371, -0.00332383, -0.00363067,
#        -0.01392093, -0.01103944,  0.07059739,  0.0679157 ,  0.06522129,
#         0.05963616,  0.05821078,  0.05068042,  0.04878665,  0.04127088,
#         0.00218548, -0.00945107,  0.01448004,  0.00480162, -0.00637172,
#        -0.02136894, -0.03695744, -0.05288739, -0.30752515,  0.24946284,
#         0.01416227,  0.01913559,  0.03500514,  0.0670973 ,  0.0451606 ,
#         0.03928555,  0.09286093,  0.0410768 , -0.0114732 ])

# %%
sns.set()
percent_variance = np.round(pca.explained_variance_ratio_* 100, decimals =2)
plt.figure(figsize=(20,8))
plt.bar(x= range(1,30), height=percent_variance, tick_label=pca_columns)
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component')
plt.title('PCA Scree Plot')

plt.show()

# %%
plt.figure(figsize = (15,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') 
plt.title('Explained Variance')
plt.show()

# %%
#plot 3 of the pca components to visualize
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=principalDF['PC1'], 
    ys=principalDF['PC2'], 
    zs=principalDF['PC3'], 
#     c= 'y', 
    cmap='tab10'
)
ax.set_xlabel('pc1')
ax.set_ylabel('pc2')
ax.set_zlabel('pc3')
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="PC1", y="PC2",
#     hue="y",
    palette=sns.color_palette("hls", 10),
    data=principalDF,
    legend="full",
    alpha=0.3
)

# %%
#examine the components
pc1 = pca.components_[0]
pc2 = pca.components_[1] 
pc3 = pca.components_[2] 
pc4 = pca.components_[3] 
pc5 = pca.components_[4] 
pc6 = pca.components_[5] 
pc7 = pca.components_[6] 
pc8 = pca.components_[7] 
pc9 = pca.components_[8] 
pc10 = pca.components_[9] 
pc11 = pca.components_[10] 
pc12 = pca.components_[11] 
pc13 = pca.components_[12] 
pc14 = pca.components_[13] 
pc15 = pca.components_[14] 
pc16 = pca.components_[15] 
pc17 = pca.components_[16] 
pc18 = pca.components_[17] 
pc19 = pca.components_[18]

# %%
# print(pc1)
# print(pc2)
# print(pc3)
# print(pc4)
# print(pc5)
# print(pc6)
# print(pc7)
# print(pc8)
# print(pc9)
# print(pc10)
# print(pc11)
# print(pc12)
# print(pc13)
# print(pc14)
# print(pc15)
# print(pc16)
# print(pc17)
# print(pc18)
# print(pc19)

# %%
# get the loadings
structure_loading_2 = pc2* np.sqrt(eig_values[1])
str_loading_2 = pd.Series(structure_loading_2, index=features)
str_loading_2.sort_values(ascending = False)
# Out:
# Uniformity of Cell Size        0.919014
# Uniformity of Cell Shape       0.910954
# Bland Chromatin                0.829081
# Marginal Adhesion              0.793891
# Normal Nucleoli                0.790633
# Single Epithelial Cell Size    0.777162
# Clump Thickness                0.742546
# Bare Nuclei_10                 0.629548
# Mitosis                        0.509275
# Bare Nuclei_8                  0.234345
# perimeter                      0.178161
# mean_perimeter                 0.171393
# Bare Nuclei_5                  0.169328
# area                           0.164593
# mean_area                      0.150499
# smoothness                     0.146902
# mean_smoothness                0.127898
# compactness                    0.123119
# Bare Nuclei_6                  0.113968
# mean_compactness               0.104152
# Bare Nuclei_9                  0.103662
# Bare Nuclei_7                  0.099142
# Bare Nuclei_4                  0.088340
# Bare Nuclei_3                  0.048291
# concave_points                 0.036542
# Bare Nuclei_2                  0.035740
# mean_concave_points            0.012117
# concavity                      0.005515
# radius                        -0.008388
# mean_radius                   -0.009162
# symmetry                      -0.016080
# mean_concavity                -0.023851
# mean_texture                  -0.027859
# Bare Nuclei_?                 -0.028954
# texture                       -0.035131
# mean_symmetry                 -0.053927
# fractal_dimension             -0.093266
# mean_fractal_dimension        -0.133467
# Bare Nuclei_1                 -0.776075
# dtype: float64

# %%
type(target_train)
# Out:
# pandas.core.series.Series

# %%
pc_to_drop = ['PC20', 'PC21', 'PC22', 'PC23', 'PC24', 'PC25', 'PC26', 'PC27', 'PC28',
       'PC29']
pca_train_df = principalDF.drop(pc_to_drop, axis = 1)

# %%
pca_train_df.columns
# Out:
# Index(['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
#        'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19'],
#       dtype='object')

# %%
pca_test_df = testprincipalDF.drop(pc_to_drop, axis = 1)

# %%
pca_test_df.columns
# Out:
# Index(['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
#        'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19'],
#       dtype='object')

# %%
smote = SMOTE(ratio='minority')
X_sm, y_sm = smote.fit_sample(pca_train_df, target_train)
print(sorted(Counter(y_sm).items()))

plot_2d_space(X_sm, y_sm, 'SMOTE over-sampling')
# Out:
# [(2.0, 340), (4.0, 340)]

# %%
tpot = TPOTClassifier(generations=50, population_size= 50, cv = 10, verbosity= 2, n_jobs= 1)
tpot.fit(X_sm,y_sm)
# Out:
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=2550, style=ProgressStyle(descrip…
# Generation 1 - Current best internal CV score: 0.9779411764705882
# Generation 2 - Current best internal CV score: 0.9779411764705882
# Generation 3 - Current best internal CV score: 0.9779411764705882
# Generation 4 - Current best internal CV score: 0.9779411764705882
# Generation 5 - Current best internal CV score: 0.9779411764705882
# Generation 6 - Current best internal CV score: 0.9794117647058824
# Generation 7 - Current best internal CV score: 0.9794117647058824
# Generation 8 - Current best internal CV score: 0.9794117647058824
# Generation 9 - Current best internal CV score: 0.9794117647058824
# Generation 10 - Current best internal CV score: 0.9794117647058824
# Generation 11 - Current best internal CV score: 0.9794117647058824
# Generation 12 - Current best internal CV score: 0.9794117647058824
# Generation 13 - Current best internal CV score: 0.9794117647058824
# Generation 14 - Current best internal CV score: 0.9794117647058824
# Generation 15 - Current best internal CV score: 0.9794117647058824
# Generation 16 - Current best internal CV score: 0.9794117647058824
# Generation 17 - Current best internal CV score: 0.9794117647058824
# Generation 18 - Current best internal CV score: 0.9794117647058824
# Generation 19 - Current best internal CV score: 0.9794117647058824
# Generation 20 - Current best internal CV score: 0.9794117647058824
# Generation 21 - Current best internal CV score: 0.9794117647058824
# Generation 22 - Current best internal CV score: 0.9794117647058824
# Generation 23 - Current best internal CV score: 0.9794117647058824
# Generation 24 - Current best internal CV score: 0.9794117647058824
# Generation 25 - Current best internal CV score: 0.9794117647058824
# Generation 26 - Current best internal CV score: 0.9794117647058824
# Generation 27 - Current best internal CV score: 0.9794117647058824
# Generation 28 - Current best internal CV score: 0.9794117647058824
# Generation 29 - Current best internal CV score: 0.9794117647058824
# Generation 30 - Current best internal CV score: 0.9794117647058824
# Generation 31 - Current best internal CV score: 0.9794117647058824
# Generation 32 - Current best internal CV score: 0.9794117647058824
# Generation 33 - Current best internal CV score: 0.9794117647058824
# Generation 34 - Current best internal CV score: 0.9794117647058824
# Generation 35 - Current best internal CV score: 0.9794117647058824
# Generation 36 - Current best internal CV score: 0.9794117647058824
# Generation 37 - Current best internal CV score: 0.9794117647058824
# Generation 38 - Current best internal CV score: 0.9794117647058824
# Generation 39 - Current best internal CV score: 0.9794117647058824
# Generation 40 - Current best internal CV score: 0.9794117647058824
# Generation 41 - Current best internal CV score: 0.9794117647058824
# Generation 42 - Current best internal CV score: 0.9794117647058824
# Generation 43 - Current best internal CV score: 0.9794117647058824
# Generation 44 - Current best internal CV score: 0.9794117647058824
# Generation 45 - Current best internal CV score: 0.9794117647058824
# Generation 46 - Current best internal CV score: 0.9794117647058824
# Generation 47 - Current best internal CV score: 0.9794117647058824
# Generation 48 - Current best internal CV score: 0.9794117647058824
# Generation 49 - Current best internal CV score: 0.9794117647058824
# Generation 50 - Current best internal CV score: 0.9794117647058824
#
# Best pipeline: LogisticRegression(GradientBoostingClassifier(CombineDFs(input_matrix, input_matrix), learning_rate=1.0, max_depth=10, max_features=0.9500000000000001, min_samples_leaf=16, min_samples_split=11, n_estimators=100, subsample=0.3), C=0.001, dual=True, penalty=l2)
# TPOTClassifier(config_dict=None, crossover_rate=0.1, cv=10,
#                disable_update_check=False, early_stop=None, generations=50,
#                max_eval_time_mins=5, max_time_mins=None, memory=None,
#                mutation_rate=0.9, n_jobs=1, offspring_size=None,
#                periodic_checkpoint_folder=None, population_size=50,
#                random_state=None, scoring=None, subsample=1.0, template=None,
#                use_dask=False, verbosity=2, warm_start=False)

# %%
tpot.export('tpot_bc_PCA_pipeline_smote.py')

# %%
tpotreg = TPOTRegressor(generations=50, population_size= 50, cv = 10, verbosity= 2, n_jobs= 1)
tpotreg.fit(X_sm,y_sm)
# Out:
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=2550, style=ProgressStyle(descrip…
# Generation 1 - Current best internal CV score: -0.0899768319225801
# Generation 2 - Current best internal CV score: -0.0899768319225801
# Generation 3 - Current best internal CV score: -0.08765619104605499
# Generation 4 - Current best internal CV score: -0.08498421853490935
# Generation 5 - Current best internal CV score: -0.08498421853490935
# Generation 6 - Current best internal CV score: -0.08338294627286136
# Generation 7 - Current best internal CV score: -0.07869803036598066
# Generation 8 - Current best internal CV score: -0.07869803036598066
# Generation 9 - Current best internal CV score: -0.07869803036598066
# Generation 10 - Current best internal CV score: -0.07869803036598066
# Generation 11 - Current best internal CV score: -0.07711095588235292
# Generation 12 - Current best internal CV score: -0.07711095588235292
# Generation 13 - Current best internal CV score: -0.0762040769823257
# Generation 14 - Current best internal CV score: -0.0762040769823257
# Generation 15 - Current best internal CV score: -0.0762040769823257
# Generation 16 - Current best internal CV score: -0.0762040769823257
# Generation 17 - Current best internal CV score: -0.07214241013071895
# Generation 18 - Current best internal CV score: -0.07108093545751634
# Generation 19 - Current best internal CV score: -0.0706637042863548
# Generation 20 - Current best internal CV score: -0.0706637042863548
# Generation 21 - Current best internal CV score: -0.0706637042863548
# Generation 22 - Current best internal CV score: -0.0706637042863548
# Generation 23 - Current best internal CV score: -0.0706637042863548
# Generation 24 - Current best internal CV score: -0.0706637042863548
# Generation 25 - Current best internal CV score: -0.06969666666666666
# Generation 26 - Current best internal CV score: -0.06969666666666666
# Generation 27 - Current best internal CV score: -0.06969666666666666
# Generation 28 - Current best internal CV score: -0.06969666666666666
# Generation 29 - Current best internal CV score: -0.06969666666666666
# Generation 30 - Current best internal CV score: -0.06958299019607844
# Generation 31 - Current best internal CV score: -0.06958299019607844
# Generation 32 - Current best internal CV score: -0.06958299019607844
# Generation 33 - Current best internal CV score: -0.0687149183006536
# Generation 34 - Current best internal CV score: -0.0687149183006536
# Generation 35 - Current best internal CV score: -0.0687149183006536
# Generation 36 - Current best internal CV score: -0.0687149183006536
# Generation 37 - Current best internal CV score: -0.0687149183006536
# Generation 38 - Current best internal CV score: -0.06752411764705882
# Generation 39 - Current best internal CV score: -0.06752411764705882
# Generation 40 - Current best internal CV score: -0.06752411764705882
# Generation 41 - Current best internal CV score: -0.06752411764705882
# Generation 42 - Current best internal CV score: -0.06752411764705882
# Generation 43 - Current best internal CV score: -0.06752411764705882
# Generation 44 - Current best internal CV score: -0.06491079179841305
# Generation 45 - Current best internal CV score: -0.06454653921195133
# Generation 46 - Current best internal CV score: -0.06454653921195133
# Generation 47 - Current best internal CV score: -0.06454653921195133
# Generation 48 - Current best internal CV score: -0.061878713584937406
# Generation 49 - Current best internal CV score: -0.061878713584937406
# Generation 50 - Current best internal CV score: -0.061878713584937406
#
# Best pipeline: ExtraTreesRegressor(RidgeCV(LassoLarsCV(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), normalize=True)), bootstrap=False, max_features=0.7000000000000001, min_samples_leaf=9, min_samples_split=2, n_estimators=100)
# TPOTRegressor(config_dict=None, crossover_rate=0.1, cv=10,
#               disable_update_check=False, early_stop=None, generations=50,
#               max_eval_time_mins=5, max_time_mins=None, memory=None,
#               mutation_rate=0.9, n_jobs=1, offspring_size=None,
#               periodic_checkpoint_folder=None, population_size=50,
#               random_state=None, scoring=None, subsample=1.0, template=None,
#               use_dask=False, verbosity=2, warm_start=False)

# %%
tpotreg.export('tpot_bc_PCA_pipline_smote_regressor')

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline, make_union
from tpot.builtins import StackingEstimator
from sklearn.preprocessing import FunctionTransformer
from copy import copy
exported_pipeline = make_pipeline(
    make_union(
        FunctionTransformer(copy),
        FunctionTransformer(copy)
    ),
    StackingEstimator(estimator=GradientBoostingClassifier(learning_rate=1.0, max_depth=10, max_features=0.9500000000000001, min_samples_leaf=16, min_samples_split=11, n_estimators=100, subsample=0.3)),
    LogisticRegression(C=0.001, dual=True, penalty="l2")
)

# %%
gbc = GradientBoostingClassifier(learning_rate=1.0, max_depth=10, max_features=0.9500000000000001, min_samples_leaf=16, min_samples_split=11, n_estimators=100, subsample=0.3)
gbc.fit(X_sm,y_sm)

gbc_pred = gbc.predict(pca_test_df)

accuracy = accuracy_score(target_test, gbc_pred)

print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 78.29%

# %%
extratrees = ExtraTreesClassifier(bootstrap=True, criterion="entropy", max_features=0.6500000000000001, min_samples_leaf=1, min_samples_split=6, n_estimators=100)
extratrees.fit(X_sm,y_sm)

extratrees_pred = extratrees.predict(pca_test_df)

accuracy = accuracy_score(target_test, extratrees_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 96.57%

# %%
def plot_confusion_matrix(y_test,model_pred):
    conf_mat = confusion_matrix(y_true=y_test, y_pred=model_pred)
    #print('Confusion matrix:\n', conf_mat)

    ax= plt.subplot()
    sns.heatmap(conf_mat, annot=True, ax = ax, fmt = 'g', cmap = 'Greens'); 

    # labels, title and ticks
    ax.set_xlabel('Predicted');ax.set_ylabel('Expected'); 
    ax.set_title('Confusion Matrix'); 
    ax.xaxis.set_ticklabels(['Benign', 'Malignant']); ax.yaxis.set_ticklabels(['Benign', 'Malignant']);
    print(classification_report(y_test,model_pred))

# %%
plot_confusion_matrix(target_test,extratrees_pred)
# Out:
#               precision    recall  f1-score   support
#
#          2.0       1.00      0.95      0.97       118
#          4.0       0.90      1.00      0.95        57
#
#     accuracy                           0.97       175
#    macro avg       0.95      0.97      0.96       175
# weighted avg       0.97      0.97      0.97       175

# %%
import warnings
exported_pipeline.fit(X_sm,y_sm)

pipeline_pred = exported_pipeline.predict()

# accuracy = accuracy_score(target_test, pipeline_pred)
# print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# /Users/harrisonmiller/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /Users/harrisonmiller/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /Users/harrisonmiller/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /Users/harrisonmiller/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /Users/harrisonmiller/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/harrisonmiller/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /Users/harrisonmiller/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)

# %%
def plot_feature_importances(model):
    n_features = pca_train_df.shape[1]
    plt.figure(figsize=(8,15))
    plt.barh(range(n_features), model.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), pca_train_df.columns.values) 
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")

# %%
plot_feature_importances(extratrees)

# %%
plot_feature_importances(gbc)
